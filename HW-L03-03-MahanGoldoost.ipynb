# %% [markdown]
# # Exercise 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime as dt

# %%
df_Hr = pd.read_csv('HRDataset_v14.csv')
df_Hr.head(5)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df_Hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df_Hr.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
df_Hr['Salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df_Hr, x='Salary', kde=True, bins=30, color='green')
plt.title('Distribution of Employee Salaries')
plt.grid(True)
plt.show()

# %% [markdown]
# As you can see in the histogram most salaries are between 46000 and 74000 and also we have some outliers in our salaries too as you can see and our data is also right skewed.

# %% [markdown]
# # Exercise 2

# %%
df_Hr['Position']
# Out:
# 0       Production Technician I
# 1                       Sr. DBA
# 2      Production Technician II
# 3       Production Technician I
# 4       Production Technician I
#                  ...
# 306    Production Technician II
# 307     Production Technician I
# 308                         CIO
# 309                Data Analyst
# 310     Production Technician I
# Name: Position, Length: 311, dtype: object

# %%
df_Hr['PositionID']
# Out:
# 0      19
# 1      27
# 2      20
# 3      19
# 4      19
#        ..
# 306    20
# 307    19
# 308     6
# 309     9
# 310    19
# Name: PositionID, Length: 311, dtype: int64

# %%
grouped_position = df_Hr.groupby('Position')['Absences'].sum().reset_index()
grouped_position.index = grouped_position.index + 1
grouped_position = grouped_position.sort_values(by='Absences', ascending=False)
grouped_position
# Out:
#                         Position  Absences
# 23       Production Technician I      1400
# 24      Production Technician II       585
# 3             Area Sales Manager       313
# 22            Production Manager       120
# 18                    IT Support        99
# 28             Software Engineer        92
# 7                   Data Analyst        88
# 32          Sr. Network Engineer        51
# 4                   BI Developer        47
# 26           Senior BI Developer        36
# 19              Network Engineer        34
# 10        Database Administrator        33
# 1                   Accountant I        26
# 25                 Sales Manager        26
# 2       Administrative Assistant        25
# 31                       Sr. DBA        24
# 15               IT Manager - DB        21
# 27       Shared Services Manager        20
# 12             Director of Sales        19
# 9                 Data Architect        17
# 6                            CIO        16
# ...

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Absences', y='Position', data=grouped_position, hue='Position', palette='viridis', legend=False)
plt.title('Absences of each Positions')
plt.show()

# %% [markdown]
# As you can see in the barplot most absences are for Production Technician I and Production Technician II and Area Sales Manager

# %% [markdown]
# # Exercise 3

# %%
df_Hr['IsTerminated'] = df_Hr['DateofTermination'].notna()
df_Hr['IsTerminated']
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 306    False
# 307     True
# 308    False
# 309    False
# 310    False
# Name: IsTerminated, Length: 311, dtype: bool

# %%
plt.Figure(figsize=(8,6))
sns.boxplot(data=df_Hr,x='IsTerminated',y='EmpSatisfaction',hue='IsTerminated',palette={False : 'green',True : 'yellow'},legend=False)
plt.xticks([False,True],['Working','NotWorking'])
plt.xlabel('Work Status')
plt.title('EmpSatisfaction between epms that are working or not')
plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see there is not much diffrenece between Emps that left the company and the ones that still working

# %% [markdown]
# # Exercise 4

# %%
df_Hr['YearOfHire'] = pd.to_datetime(df_Hr['DateofHire']).dt.year
df_Hr['YearOfHire']
# Out:
# 0      2011
# 1      2015
# 2      2011
# 3      2008
# 4      2011
#        ...
# 306    2014
# 307    2008
# 308    2010
# 309    2015
# 310    2014
# Name: YearOfHire, Length: 311, dtype: int32

# %%
grouped_Hired = df_Hr.groupby('YearOfHire')['EmpID'].count().reset_index()
grouped_Hired
# Out:
#     YearOfHire  EmpID
# 0         2006      1
# 1         2007      2
# 2         2008      3
# 3         2009      7
# 4         2010      9
# 5         2011     83
# 6         2012     45
# 7         2013     44
# 8         2014     60
# 9         2015     36
# 10        2016     14
# 11        2017      6
# 12        2018      1

# %%
grouped_Hired.index = grouped_Hired.index + 1
grouped_Hired = grouped_Hired.sort_values(by='EmpID',ascending=False)
grouped_Hired
# Out:
#     YearOfHire  EmpID
# 7         2011     83
# 10        2014     60
# 8         2012     45
# 9         2013     44
# 11        2015     36
# 12        2016     14
# 6         2010      9
# 5         2009      7
# 13        2017      6
# 4         2008      3
# 3         2007      2
# 2         2006      1
# 14        2018      1

# %%
plt.Figure(figsize=(12,8))
sns.barplot(data=grouped_Hired,x='YearOfHire',y='EmpID',hue='YearOfHire',palette='tab10',legend=False)
plt.title('Hired Emps Per Year')
plt.xlabel('Hired Year')
plt.ylabel('Count Of Hired Emps')
plt.tight_layout()
plt.show()

# %% [markdown]
# The most emps hired are for years: 2011 and 2014

# %% [markdown]
# # Exercise 5

# %%
df_Hr[['SpecialProjectsCount','Absences']]
# Out:
#      SpecialProjectsCount  Absences
# 0                       0         1
# 1                       6        17
# 2                       0         3
# 3                       0        15
# 4                       0         2
# ..                    ...       ...
# 306                     0        13
# 307                     0         4
# 308                     6        16
# 309                     5        11
# 310                     0         2
#
# [311 rows x 2 columns]

# %%
plt.Figure(figsize=(7,5))
sns.scatterplot(data=df_Hr,x='SpecialProjectsCount',y='Absences',hue='SpecialProjectsCount',palette='viridis',legend=False)
plt.title('Relation Between Special Projects And Absences')
plt.xlabel('Special Projects')
plt.ylabel('Absences')
plt.show()

# %%
corr_SpA = df_Hr[['SpecialProjectsCount','Absences']].corr()
corr_SpA
# Out:
#                       SpecialProjectsCount  Absences
# SpecialProjectsCount              1.000000 -0.020452
# Absences                         -0.020452  1.000000

# %%
plt.Figure(figsize=(6,4))
sns.heatmap(data=corr_SpA, annot=True, cmap='crest', fmt=".2f", vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# There is almost no relationship between special projects count and absences
